# %%
# importing libraries
from bs4 import BeautifulSoup
import requests

# %%
response = requests.get('https://books.toscrape.com/')
response
# Out:
# <Response [200]>

# %%
html_data = response.text

# %%
data = BeautifulSoup(html_data,'html.parser')

# %% [markdown]
# print(data.prettify)

# %%
data.find('title').text.strip()
# Out:
# 'All products | Books to Scrape - Sandbox'

# %%
book_tag = data.find_all('article',class_='product_pod')
book_tag
# Out:
# [<article class="product_pod">
#  <div class="image_container">
#  <a href="catalogue/a-light-in-the-attic_1000/index.html"><img alt="A Light in the Attic" class="thumbnail" src="media/cache/2c/da/2cdad67c44b002e7ead0cc35693c0e8b.jpg"/></a>
#  </div>
#  <p class="star-rating Three">
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  </p>
#  <h3><a href="catalogue/a-light-in-the-attic_1000/index.html" title="A Light in the Attic">A Light in the ...</a></h3>
#  <div class="product_price">
#  <p class="price_color">Â£51.77</p>
#  <p class="instock availability">
#  <i class="icon-ok"></i>
#
#          In stock
#
#  </p>
#  <form>
#  <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>
#  </form>
#  </div>
#  </article>,
#  <article class="product_pod">
#  <div class="image_container">
# ...

# %%
len(book_tag)
# Out:
# 20

# %%
book_tag = book_tag[0]
book_tag
# Out:
# <article class="product_pod">
# <div class="image_container">
# <a href="catalogue/a-light-in-the-attic_1000/index.html"><img alt="A Light in the Attic" class="thumbnail" src="media/cache/2c/da/2cdad67c44b002e7ead0cc35693c0e8b.jpg"/></a>
# </div>
# <p class="star-rating Three">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>
# <h3><a href="catalogue/a-light-in-the-attic_1000/index.html" title="A Light in the Attic">A Light in the ...</a></h3>
# <div class="product_price">
# <p class="price_color">Â£51.77</p>
# <p class="instock availability">
# <i class="icon-ok"></i>
#
#         In stock
#
# </p>
# <form>
# <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>
# </form>
# </div>
# </article>

# %%
# Title
title = book_tag.find('a' , title=True)['title']
title
# Out:
# 'A Light in the Attic'

# %%
# Rating 
rating = book_tag.find('p')['class'][1]
rating
# Out:
# 'Three'

# %%
# Price
price = book_tag.find('p',class_='price_color').text[1:]
price
# Out:
# '£51.77'

# %%
# Book Link
link = 'https://books.toscrape.com/'+book_tag.find('a')['href']
link
# Out:
# 'https://books.toscrape.com/catalogue/a-light-in-the-attic_1000/index.html'

# %%
def get_details(book_tag):
    title = book_tag.find('a' , title=True)['title']
    rating = book_tag.find('p')['class'][1]
    price = book_tag.find('p',class_='price_color').text[1:]
    link = 'https://books.toscrape.com/'+book_tag.find('a')['href']
    return title, rating, price, link

# %%
url ='https://books.toscrape.com/'

# %%
def get_data(url):
    # Takes Url and returns a soup object
    response = requests.get(url)
    if response_code == 200:
        return bs(response.text)
    else:
        return None
    
def get_books(url):
    # Extracts details from all the book tags
    data = get_data(url)
    book_tags = data.find_all('article',class_='product_pod')
    
    books = []
    for i in book_tags:
        books.append(get_details(i))
    return books

# %%
len(books)
# Out:
# 80

# %%
# Creating a dataframe using the pandas
df = pd.DataFrame(books , columns = ['Title', 'Rating', 'Price', 'Link'])

# %%
df.to_csv('books.csv')
